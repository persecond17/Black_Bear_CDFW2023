# %%
import pandas as pd
import numpy as np
import re
import string
from datetime import datetime

import nltk
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('merge_unique.csv').drop(columns=['Unnamed: 0','index'])
df = df.astype({'tweet_id':'str', 'author_id':'str', 'place_id':'str'})
df.created_datetime = pd.to_datetime(df.created_datetime)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316749 entries, 0 to 316748
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   tweet_id          316749 non-null  object
#  1   created_datetime  316749 non-null  datetime64[ns]
#  2   content           316749 non-null  object
#  3   author_id         316749 non-null  object
#  4   place_id          316749 non-null  object
#  5   location          308672 non-null  object
#  6   longitude         316749 non-null  float64
#  7   latitude          316749 non-null  float64
#  8   county            316749 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 21.7+ MB

# %% [markdown]
# # Temporal Analysis: Frequency of Tweets Across Years
#
# #### Note: Tweets related to "bears" may not necessarily be about actual bear sightings or encounters. Therefore, the distribution presented here may not be representative of the actual frequency of such scenarios. We have provided this visualization for basic understanding purposes only.

# %%
min(df.created_datetime), max(df.created_datetime)
# Out:
# (Timestamp('2010-03-09 00:00:00'), Timestamp('2022-12-31 00:00:00'))

# %%
date_tt = pd.to_datetime(list(df.created_datetime))
ratio_tt = [[year, round(num/len(date_tt)*100,1)] for year, num in Counter(date_tt.year).items()]
ratio_tt_df = pd.DataFrame(ratio_tt, columns=['year', 'ratio(%)'])

fig = px.bar(ratio_tt_df, 
             x="year", 
             y="ratio(%)",
             text='ratio(%)',
             title="Tweets related to 'bear' yearly distribution (Twitter)")
fig.show()
# fig.write_html("twitter_yearly_ratio.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="286ffbb2-bc63-4834-8849-4172723d0c14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("286ffbb2-bc63-4834-8849-4172723d0c14")) {                    Plotly.newPlot(                        "286ffbb2-bc63-4834-8849-4172723d0c14",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>ratio(%)=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[4.6,8.9,1.5,7.5,6.5,4.6,4.7,7.7,10.3,12.6,11.0,11.4,8.6],"textposition":"auto","x":[2011,2018,2010,2019,2020,2021,2022,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[4.6,8.9,1.5,7.5,6.5,4.6,4.7,7.7,10.3,12.6,11.0,11.4,8.6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":" ...

# %% [markdown]
# # Geospatial Analysis: Distribution of Tweets at County-level

# %%
county_tt_count = sorted(Counter(df.county).items(), key=lambda x:-x[1])
geo_tt = [[county, round(num/len(df)*100,1)] for county, num in county_tt_count[:10]]
geo_tt_df = pd.DataFrame(geo_tt, columns=['county', 'ratio(%)'])

fig = px.bar(geo_tt_df, 
             x="county", 
             y="ratio(%)",
             text='ratio(%)',
             title="Tweets related to 'bear' geo distribution (Twitter)")
fig.show()
# fig.write_html("twitter_geo_ratio.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="76f673db-8824-48bc-8bad-a570ba478b3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76f673db-8824-48bc-8bad-a570ba478b3a")) {                    Plotly.newPlot(                        "76f673db-8824-48bc-8bad-a570ba478b3a",                        [{"alignmentgroup":"True","hovertemplate":"county=%{x}<br>ratio(%)=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[24.0,22.1,7.3,7.1,6.0,3.4,3.4,3.3,2.8,2.0],"textposition":"auto","x":["LOS ANGELES","SAN BERNARDINO","ORANGE","SAN DIEGO","SAN FRANCISCO","SANTA CLARA","RIVERSIDE","MADERA","CONTRA COSTA","YOLO"],"xaxis":"x","y":[24.0,22.1,7.3,7.1,6.0,3.4,3.4,3.3,2.8,2.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay"," ...

# %% [markdown]
# # Textual Analysis: Word Cloud of Most Frequent Words in Tweets

# %%
def clear_text(df):
    contents = ''.join(df.content.values)
    contents = [c for c in contents if c not in string.punctuation]
    contents = ''.join(contents).lower().replace("’","'").replace('”', "'")
    
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF" # chinese char
        "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r' ',contents)

# %%
def stemmer(contents):
    words = contents.split()
    words = [w for w in words if w not in ENGLISH_STOP_WORDS]

    stemmer = PorterStemmer()
    stemmed = [stemmer.stem(w) for w in words]
    return stemmed

# %%
contents = clear_text(df)
stemmed = stemmer(contents)
counter = Counter(stemmed)
wtuples = counter.most_common(100)
wdict = dict(wtuples)

# %%
wordcloud = WordCloud(background_color='white', width=800, height=500, max_words=80)
wordcloud.fit_words(wdict)

fig = plt.figure(figsize=(8, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Reference: Time & geo distributions of iNaturalist data
#
# #### Note: The iNaturalist dataset contains 5545 records of observations or encounters of "American Black Bear" within California, reported by observers between 1988 and 2022. To extract bear-encountering information from bear-related tweets, we use the distribution of this dataset as a reference and visualize it.
#
#
# #### We will visualize the yearly and monthly patterns of the tweets, as well as their geo distribution at the county level. Although most tweets have a "place guess" feature, they are not standardized and are difficult to compare. Therefore, we will assign a county label to each tweet based on the coordinate features provided by iNaturalist.

# %%
ina = pd.read_csv('iNaturalist_blackbears_CA.csv')
ina.head(3).T
# Out:
#                                                                                   0  \
# id                                                                             1006
# observed_on_string                                              2006-06-27 18:38:17
# observed_on                                                              2006-06-27
# time_observed_at                                            2006-06-28 01:38:17 UTC
# time_zone                                                Pacific Time (US & Canada)
# user_id                                                                           1
# user_login                                                                    kueda
# user_name                                                             Ken-ichi Ueda
# created_at                                                  2008-12-16 07:08:31 UTC
# updated_at                                                  2021-01-26 21:44:34 UTC
# quality_grade                                                              research
# license                                                                         CC0
# url                                    http://www.inaturalist.org/observations/1006
# image_url                         https://inaturalist-open-data.s3.amazonaws.com...
# sound_url                                                                       NaN
# tag_list                                                                        NaN
# description                       Location is approximate, but it was right by t...
# num_identification_agreements                                                     5
# num_identification_disagreements                                                  0
# captive_cultivated                                                            False
# oauth_application_id                                                            NaN
# place_guess                                                   Sequoia National Park
# latitude                                                                   36.56076
# longitude                                                               -118.767601
# positional_accuracy                                                             NaN
# private_place_guess                                                             NaN
# private_latitude                                                                NaN
# private_longitude                                                               NaN
# public_positional_accuracy                                                      NaN
# geoprivacy                                                                      NaN
# taxon_geoprivacy                                                               open
# coordinates_obscured                                                          False
# positioning_method                                                              NaN
# positioning_device                                                              NaN
# species_guess                                                             Ours noir
# scientific_name                                                    Ursus americanus
# common_name                                                     American Black Bear
# iconic_taxon_name                                                          Mammalia
# taxon_id                                                                      41638
#
#                                                                                   1  \
# id                                                                            12388
# observed_on_string                                                       2007-09-07
# observed_on                                                              2007-09-07
# time_observed_at                                                                NaN
# time_zone                                                Pacific Time (US & Canada)
# user_id                                                                         710
# user_login                                                              johngcramer
# user_name                                                           John Cramer III
# created_at                                                  2011-03-07 04:37:36 UTC
# updated_at                                                  2021-08-17 23:13:26 UTC
# quality_grade                                                              research
# license                                                                         NaN
# url                                   http://www.inaturalist.org/observations/12388
# image_url                         http://static.inaturalist.org/photos/24498/med...
# sound_url                                                                       NaN
# tag_list                                                                        NaN
# description                                                     Is it a brown bear?
# num_identification_agreements                                                     2
# num_identification_disagreements                                                  0
# captive_cultivated                                                            False
# oauth_application_id                                                            NaN
# place_guess                                                  Yosemite National Park
# latitude                                                                  37.770596
# longitude                                                               -119.510771
# positional_accuracy                                                             NaN
# private_place_guess                                                             NaN
# private_latitude                                                                NaN
# private_longitude                                                               NaN
# public_positional_accuracy                                                      NaN
# geoprivacy                                                                      NaN
# taxon_geoprivacy                                                               open
# coordinates_obscured                                                          False
# positioning_method                                                              NaN
# positioning_device                                                              NaN
# species_guess                                                 California Black Bear
# scientific_name                                     Ursus americanus californiensis
# common_name                                                   California Black Bear
# iconic_taxon_name                                                          Mammalia
# taxon_id                                                                     126772
#
#                                                                                   2
# id                                                                            13610
# observed_on_string                                                       2009-06-14
# observed_on                                                              2009-06-14
# time_observed_at                                                                NaN
# time_zone                                                Pacific Time (US & Canada)
# user_id                                                                         933
# user_login                                                              chriswbrown
# user_name                                                               Chris Brown
# created_at                                                  2011-04-02 04:50:53 UTC
# updated_at                                                  2021-08-18 21:21:48 UTC
# quality_grade                                                              research
# license                                                                    CC-BY-NC
# url                                   http://www.inaturalist.org/observations/13610
# image_url                         http://static.inaturalist.org/photos/27007/med...
# sound_url                                                                       NaN
# tag_list                                                                        NaN
# description                                                     Careless campers...
# num_identification_agreements                                                     5
# num_identification_disagreements                                                  0
# captive_cultivated                                                            False
# oauth_application_id                                                            NaN
# place_guess                                                  Yosemite National Park
# latitude                                                                  37.770596
# longitude                                                               -119.510771
# positional_accuracy                                                             NaN
# private_place_guess                                                             NaN
# private_latitude                                                                NaN
# private_longitude                                                               NaN
# public_positional_accuracy                                                      NaN
# geoprivacy                                                                      NaN
# taxon_geoprivacy                                                               open
# coordinates_obscured                                                          False
# positioning_method                                                              NaN
# positioning_device                                                              NaN
# species_guess                                                   American black bear
# scientific_name                                                    Ursus americanus
# common_name                                                     American Black Bear
# iconic_taxon_name                                                          Mammalia
# taxon_id                                                                      41638

# %% [markdown]
# ## Yearly and monthly patterns of iNaturalist data

# %%
date = pd.to_datetime([date[:7] for date in ina.observed_on])
min(date), max(date)
# Out:
# (Timestamp('1988-06-01 00:00:00'), Timestamp('2022-11-01 00:00:00'))

# %%
date_count = Counter(date)
date_df = pd.DataFrame(date_count.items(), columns=['date', 'frequency'])
fig = px.bar(date_df, 
                 x="date", 
                 y="frequency",
                 title="Yearly pattern of bears encountering frequency in CA (iNaturalist)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1f3b2c64-5355-4bd8-998b-5fd29cc32227" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f3b2c64-5355-4bd8-998b-5fd29cc32227")) {                    Plotly.newPlot(                        "1f3b2c64-5355-4bd8-998b-5fd29cc32227",                        [{"alignmentgroup":"True","hovertemplate":"date=%{x}<br>frequency=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2006-06-01T00:00:00","2007-09-01T00:00:00","2009-06-01T00:00:00","2011-08-01T00:00:00","2007-04-01T00:00:00","2011-11-01T00:00:00","2003-06-01T00:00:00","2009-04-01T00:00:00","2009-05-01T00:00:00","2012-05-01T00:00:00","2012-08-01T00:00:00","2005-06-01T00:00:00","2012-09-01T00:00:00","2010-06-01T00:00:00","2012-10-01T00:00:00","2012-12-01T00:00:00","2005-08-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-04-01T00:00:00","2013-03-01T00:00:00","2006-07-01T00:00:00","2012-04-01T00:00:00","2013-07-01T00:00:00","2010-08-01T00:00:00","2003-11-01T00:00:00","2013-08-01T00:00:00","2005-04-01T00:00:00","2012-03-01T00:00:00","1992-08-01T00:00:00","2013-09-01T00:00:00","2001-07-01T00:00:00","2004-09-01T00:00:00","2008-07-01T00:00:00","2009-10-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2012-11-01T00:00:00","2011-12-01T00:00:00","2013-12-01T00:00:00","2012-07-01T00:00:00","1988-06-01T00:00:00","2014-02-01T00:00:00","2014-04-01T00:00:00","2004-11-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2010-04-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2003-07-01T00:00:00","2011-05-01T00:00:00","2015-04-01T00:00:00","2015-03-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2010-10-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2007-07-01T00:00:00","2009-07-01T00:00:00","2009-08-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2008-06-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2010-05-01T00:00:00","2016-09-01T00:00:00","2009-09-01T00:00:00","2016-10-01T00:00:00","2016-01-01T00:00:00","2008-04-01T00:00:00","2016-11-01T00:00:00","2008-08-01T00:00:00","2016-12-01T00:00:00","2015-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2006-08-01T00:00:00","2017-02-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2011-10-01T00:00:00","2017-07-01T00:00:00","2012-06-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2005-07-01T00:00:00","2017-10-01T00:00:00","2000-09-01T00:00:00","2004-06-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2004-07-01T00:00:00","2003-09-01T00:00:00","2003-08-01T00:00:00","2008-05-01T00:00:00","2009-02-01T00:00:00","2009-03-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2017-01-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2010-07-01T00:00:00","2008-09-01T00:00:00","2005-09-01T00:00:00","2010-09-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2011-06-01T00:00:00","2008-12-01T00:00:00","2007-08-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2007-05-01T00:00:00","2019-08-01T00:00:00","2006-10-01T00:00:00","2019-09-01T00:00:00","2006-09-01T00:00:00","2009-11-01T00:00:00","2019-10-01T00:00:00","2008-02-01T00:00:00","2019-11-01T00:0 ...

# %%
ratio = [[month, round(num/len(date)*100,1)] for month, num in Counter(date.month).items()]
ratio_df = pd.DataFrame(ratio, columns=['month', 'ratio(%)'])
fig = px.bar(ratio_df, 
             x="month", 
             y="ratio(%)",
             text='ratio(%)',
             title="Monthly pattern of bears encountering frequency in CA (iNaturalist)")
fig.show()
# fig.write_html("inaturalist_monthly_ratio.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8bad3245-3f19-4fba-9130-cfae93c6e1a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bad3245-3f19-4fba-9130-cfae93c6e1a5")) {                    Plotly.newPlot(                        "8bad3245-3f19-4fba-9130-cfae93c6e1a5",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>ratio(%)=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[15.3,12.3,15.3,6.2,4.9,11.5,9.7,2.7,3.1,15.8,1.4,1.8],"textposition":"auto","x":[6,9,8,4,11,5,10,12,3,7,2,1],"xaxis":"x","y":[15.3,12.3,15.3,6.2,4.9,11.5,9.7,2.7,3.1,15.8,1.4,1.8],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo"," ...

# %% [markdown]
# ## County-level distribution of iNaturalist data

# %%
coor = ina[['longitude', 'latitude']]
coor.longitude.astype('float')
coor.latitude.astype('float')
coor = coor.values.tolist()
results = sorted(coor, key=lambda x:x[0])

# %%
# Assign a unified county label to each record based on the coordinates, 
# and then collect them into a list.
as_county = []
grid_df = pd.read_csv('grid_out.csv').sort_values(by=['xmin'])

for i in range(len(results)):
    long, lat = results[i][0], results[i][1]
    loc = ''
    for j in range(len(grid_df)):
        grid_record = grid_df.iloc[j]
        if long <= grid_record.xmax and long >= grid_record.xmin:
            if lat <= grid_record.ymax and lat >= grid_record.ymin:
                loc = grid_record.county
                break
    as_county.append(loc)
len(as_county)
# Out:
# 5545

# %%
county_count = sorted(Counter(as_county).items(), key=lambda x:-x[1])
county_count[:10]
# Out:
# [('HUMBOLDT', 1228),
#  ('TULARE', 461),
#  ('LOS ANGELES', 406),
#  ('MARIPOSA', 345),
#  ('EL DORADO', 298),
#  ('TUOLUMNE', 272),
#  ('PLACER', 220),
#  ('VENTURA', 169),
#  ('SAN BERNARDINO', 166),
#  ('FRESNO', 164)]

# %%
geo = [[county, round(num/len(as_county)*100,1)] for county, num in county_count[:10]]
geo_df = pd.DataFrame(geo, columns=['county', 'ratio(%)'])
fig = px.bar(geo_df, 
             x="county", 
             y="ratio(%)",
             text='ratio(%)',
             title="Bears encountering top 10 counties in CA (iNaturalist)")
fig.show()
# fig.write_html("inaturalist_geo_ratio.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6d0b74a9-29ca-4c09-b54c-0b9f7adcbc4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d0b74a9-29ca-4c09-b54c-0b9f7adcbc4c")) {                    Plotly.newPlot(                        "6d0b74a9-29ca-4c09-b54c-0b9f7adcbc4c",                        [{"alignmentgroup":"True","hovertemplate":"county=%{x}<br>ratio(%)=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[22.1,8.3,7.3,6.2,5.4,4.9,4.0,3.0,3.0,3.0],"textposition":"auto","x":["HUMBOLDT","TULARE","LOS ANGELES","MARIPOSA","EL DORADO","TUOLUMNE","PLACER","VENTURA","SAN BERNARDINO","FRESNO"],"xaxis":"x","y":[22.1,8.3,7.3,6.2,5.4,4.9,4.0,3.0,3.0,3.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"soli ...
